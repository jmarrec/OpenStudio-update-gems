# %%
import os
import re
import pandas as pd
import numpy as np

# pip install PyGithub
from github import Github

# First create a Github instance:
g = Github("jmarrec", "<web_password>")

# %% [markdown]
# # Find NREL repos that may have a gemspec file

# %% [markdown]
# ## Filter on repos that have 'Ruby' as a language

# %%
repo_names = []
ruby_repo_names = []
repo = None
for repo in g.get_organization('NREL').get_repos():
    repo_name = repo.name
    # print(repo_name)
    repo_names.append(repo_name)
    if 'Ruby' in repo.get_languages():
        ruby_repo_names.append(repo_name)

# %% [markdown]
# # Loop on all repos that have ruby, parse *.gemspec file

# %%
RE_VERSION = re.compile(r'^\s+\w+\.add_(?P<type>(?:.*?_)?dependency)\s+[\'\"](?P<name>.*?)[\'\"]\s*,\s*[\'\"](?P<version>.*?)[\'\"]')

# %%
# List of branches that are open and aim to bump dependencies
# If not specified here, will use develop

bump_branches = {
 'NREL/OpenStudio-workflow-gem': 'Bump_deps',
 'NREL/OpenStudio-measure-tester-gem': 'upgrade-dependencies',
 'NREL/openstudio-common-measures-gem': 'feature/13-openstudio-3.x',
}


gemspecs = {}
for ruby_repo_name in ruby_repo_names:
    repo = g.get_user('NREL').get_repo(ruby_repo_name)
    repo_full_name = repo.full_name
    
    if (repo_full_name in bump_branches):
        b = repo.get_branch(bump_branches[repo_full_name])
        print("For {r}, getting branch {b} at {s}".format(
          r=repo_full_name, b=bump_branches[repo_full_name], s=b.commit.sha))
        content_files = repo.get_contents('.', ref=b.commit.sha)
    else:
        content_files = repo.get_contents('.')
        
    for content_file in content_files:
    
        if os.path.splitext(content_file.name)[1] == '.gemspec':
            gemspecs[repo_full_name] = []
            content = content_file.decoded_content.decode()

            for line in content.splitlines():
                m = RE_VERSION.search(line)
                if m:
                    d = m.groupdict()
                    gemspecs[repo_full_name].append(d)
# Out:
# For NREL/OpenStudio-workflow-gem, getting branch Bump_deps at e191192cebe86df57b323bfb21e16b4e2b5ac2bc
# For NREL/OpenStudio-measure-tester-gem, getting branch upgrade-dependencies at f0aaf5ad0383105070162be58663c3d46cb7e24e
# For NREL/openstudio-common-measures-gem, getting branch feature/13-openstudio-3.x at fbcd76d8b426b538acc874f0d308e969507c29c4

# %% [markdown]
# # Analyze versions

# %% [raw]
# # Reload?
# gemspecs = {'NREL/capistrano_nrel_ext': [],
#  'NREL/bcl-gem': [],
#  'NREL/OpenStudio-analysis-gem': [{'type': 'dependency',
#    'name': 'bcl',
#    'version': '~> 0.5.8',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'dependency',
#    'name': 'dencity',
#    'version': '~> 0.1.0',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'dependency',
#    'name': 'faraday',
#    'version': '~> 0.14',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'dependency',
#    'name': 'nokogiri',
#    'version': '~> 1.8.2',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'dependency',
#    'name': 'roo',
#    'version': '~> 2.7.1',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'dependency',
#    'name': 'rubyzip',
#    'version': '~> 1.2',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'dependency',
#    'name': 'semantic',
#    'version': '~> 1.4',
#    'gem': 'NREL/OpenStudio-analysis-gem'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 12.3.1',
#    'gem': 'NREL/OpenStudio-analysis-gem'}],
#  'NREL/OpenStudio-aws-gem': [{'type': 'dependency',
#    'name': 'aws-sdk-core',
#    'version': '= 2.2.37',
#    'gem': 'NREL/OpenStudio-aws-gem'},
#   {'type': 'dependency',
#    'name': 'net-scp',
#    'version': '= 2.0.0',
#    'gem': 'NREL/OpenStudio-aws-gem'},
#   {'type': 'dependency',
#    'name': 'net-ssh',
#    'version': '= 4.2.0',
#    'gem': 'NREL/OpenStudio-aws-gem'},
#   {'type': 'dependency',
#    'name': 'semantic',
#    'version': '~> 1.4',
#    'gem': 'NREL/OpenStudio-aws-gem'},
#   {'type': 'dependency',
#    'name': 'sshkey',
#    'version': '~> 2.0',
#    'gem': 'NREL/OpenStudio-aws-gem'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 12.3',
#    'gem': 'NREL/OpenStudio-aws-gem'}],
#  'NREL/openstudio-standards': [{'type': 'development_dependency',
#    'name': 'nokogiri',
#    'version': '<= 1.6.8.1',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 1.9',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 10.0',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'yard',
#    'version': '~> 0.9',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'rubocop',
#    'version': '0.68.1',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'rubocop-checkstyle_formatter',
#    'version': '~> 0.1.1',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'minitest-ci',
#    'version': '<= 5.10.3',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'rubyXL',
#    'version': '3.3.8',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'activesupport',
#    'version': '4.2.5',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'public_suffix',
#    'version': '3.0.3',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'faraday',
#    'version': '0.15.4',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'google-api-client',
#    'version': '0.8.6',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'rest-client',
#    'version': '2.0.2',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'aes',
#    'version': '0.5.0',
#    'gem': 'NREL/openstudio-standards'},
#   {'type': 'development_dependency',
#    'name': 'roo',
#    'version': '2.7.1',
#    'gem': 'NREL/openstudio-standards'}],
#  'NREL/OpenStudio-Recommendation-Engine': [],
#  'NREL/OpenStudio-workflow-gem': [{'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 2.1',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'rspec',
#    'version': '~> 3.9',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'json-schema',
#    'version': '~> 2.8.0',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'ci_reporter',
#    'version': '~> 2.0.0',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'ci_reporter_rspec',
#    'version': '~> 1.0.0',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'builder',
#    'version': '~> 3.2.4',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'coveralls',
#    'version': '~> 0.8.21',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'parallel',
#    'version': '~> 1.19.1',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'rubocop',
#    'version': '~> 0.80.1',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'rubocop-checkstyle_formatter',
#    'version': '~> 0.4.0',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'public_suffix',
#    'version': '~> 4.0.3',
#    'gem': 'NREL/OpenStudio-workflow-gem'},
#   {'type': 'development_dependency',
#    'name': 'rainbow',
#    'version': '~> 3.0.0',
#    'gem': 'NREL/OpenStudio-workflow-gem'}],
#  'NREL/dencity-scripts': [{'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 1.7',
#    'gem': 'NREL/dencity-scripts'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 10.0',
#    'gem': 'NREL/dencity-scripts'}],
#  'NREL/dencity-gem': [{'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 1.10',
#    'gem': 'NREL/dencity-gem'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 10.0',
#    'gem': 'NREL/dencity-gem'}],
#  'NREL/bricr': [{'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 1.17.1',
#    'gem': 'NREL/bricr'},
#   {'type': 'runtime_dependency',
#    'name': 'parallel',
#    'version': '~> 1.12',
#    'gem': 'NREL/bricr'}],
#  'NREL/haystack_ruby': [],
#  'NREL/OpenStudio-measure-tester-gem': [{'type': 'dependency',
#    'name': 'git',
#    'version': '~> 1.6.0',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'dependency',
#    'name': 'minitest',
#    'version': '~> 5.14.0',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'dependency',
#    'name': 'minitest-reporters',
#    'version': '~> 1.4.2',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'dependency',
#    'name': 'rake',
#    'version': '~> 13.0',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'dependency',
#    'name': 'rubocop',
#    'version': '~> 0.80.1',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'dependency',
#    'name': 'rubocop-checkstyle_formatter',
#    'version': '~> 0.4.0',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'dependency',
#    'name': 'simplecov',
#    'version': '~> 0.18.2',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 2.1',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'},
#   {'type': 'development_dependency',
#    'name': 'rspec',
#    'version': '~> 3.9',
#    'gem': 'NREL/OpenStudio-measure-tester-gem'}],
#  'NREL/simplecov': [{'type': 'dependency',
#    'name': 'simplecov-html',
#    'version': '~> 0.10.0',
#    'gem': 'NREL/simplecov'},
#   {'type': 'dependency',
#    'name': 'docile',
#    'version': '~> 1.1',
#    'gem': 'NREL/simplecov'},
#   {'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 1.9',
#    'gem': 'NREL/simplecov'}],
#  'NREL/openstudio-extension-gem': [{'type': 'dependency',
#    'name': 'bundler',
#    'version': '~> 2.1',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'dependency',
#    'name': 'openstudio-workflow',
#    'version': '~> 1.3.4',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'dependency',
#    'name': 'openstudio_measure_tester',
#    'version': '~> 0.2.0',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'dependency',
#    'name': 'parallel',
#    'version': '~> 1.12.0',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'development_dependency',
#    'name': 'github_api',
#    'version': '~> 0.18.0',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 12.3',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'development_dependency',
#    'name': 'rspec',
#    'version': '~> 3.7',
#    'gem': 'NREL/openstudio-extension-gem'},
#   {'type': 'development_dependency',
#    'name': 'rubocop',
#    'version': '~> 0.54.0',
#    'gem': 'NREL/openstudio-extension-gem'}],
#  'NREL/openstudio-model-articulation-gem': [{'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 1.14',
#    'gem': 'NREL/openstudio-model-articulation-gem'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 12.3',
#    'gem': 'NREL/openstudio-model-articulation-gem'},
#   {'type': 'development_dependency',
#    'name': 'rspec',
#    'version': '3.7.0',
#    'gem': 'NREL/openstudio-model-articulation-gem'},
#   {'type': 'development_dependency',
#    'name': 'rubocop',
#    'version': '~> 0.54.0',
#    'gem': 'NREL/openstudio-model-articulation-gem'},
#   {'type': 'dependency',
#    'name': 'openstudio-common-measures',
#    'version': '~> 0.1.2',
#    'gem': 'NREL/openstudio-model-articulation-gem'},
#   {'type': 'dependency',
#    'name': 'openstudio-standards',
#    'version': '~> 0.2.10',
#    'gem': 'NREL/openstudio-model-articulation-gem'}],
#  'NREL/openstudio-gems': [{'type': 'dependency',
#    'name': 'openstudio-extension',
#    'version': '0.2.0',
#    'gem': 'NREL/openstudio-gems'},
#   {'type': 'dependency',
#    'name': 'openstudio-workflow',
#    'version': '1.3.4',
#    'gem': 'NREL/openstudio-gems'},
#   {'type': 'dependency',
#    'name': 'openstudio_measure_tester',
#    'version': '0.2.0',
#    'gem': 'NREL/openstudio-gems'},
#   {'type': 'dependency',
#    'name': 'parallel',
#    'version': '1.12.1',
#    'gem': 'NREL/openstudio-gems'},
#   {'type': 'dependency',
#    'name': 'json_pure',
#    'version': '2.2',
#    'gem': 'NREL/openstudio-gems'},
#   {'type': 'development_dependency',
#    'name': 'bundler',
#    'version': '~> 2.1',
#    'gem': 'NREL/openstudio-gems'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 12.3',
#    'gem': 'NREL/openstudio-gems'}],
#  'NREL/openstudio-common-measures-gem': [{'type': 'dependency',
#    'name': 'bundler',
#    'version': '~> 2.1',
#    'gem': 'NREL/openstudio-common-measures-gem'},
#   {'type': 'dependency',
#    'name': 'openstudio-extension',
#    'version': '~> 0.2.0',
#    'gem': 'NREL/openstudio-common-measures-gem'},
#   {'type': 'dependency',
#    'name': 'parallel',
#    'version': '~> 1.12.0',
#    'gem': 'NREL/openstudio-common-measures-gem'},
#   {'type': 'development_dependency',
#    'name': 'github_api',
#    'version': '~> 0.18.0',
#    'gem': 'NREL/openstudio-common-measures-gem'},
#   {'type': 'development_dependency',
#    'name': 'rake',
#    'version': '~> 12.3',
#    'gem': 'NREL/openstudio-common-measures-gem'},
#   {'type': 'development_dependency',
#    'name': 'rspec',
#    'version': '~> 3.7',
#    'gem': 'NREL/openstudio-common-measures-gem'},
#   {'type': 'development_dependency',
#    'name': 'rubocop',
#    'version': '~> 0.54.0',
#    'gem': 'NREL/openstudio-common-measures-gem'}],
#  'NREL/pycall.rb': []}

# %%
empty_gemspecs = [k for k, v in gemspecs.items() if not v]

# %%
for k, v in gemspecs.items():
    for x in v:
        x.update({'gem': k})
        #x.pop('gem')
        
gemspecs_list = []

for k, v in gemspecs.items():
    for x in v:
        gemspecs_list.append(x)

# %%
df = pd.DataFrame(gemspecs_list)[['gem', 'name', 'version', 'type']]

# %%
# df.pivot(index='name', columns='gem', values='version')

df_piv = df.pivot(index='gem', columns='name', values=['version', 'type'])

# %% [markdown]
# ## Visualize

# %%
def check_versions(col):
    """
    col is a pd.Series for a single gem used in our projects
    
    Return:
    * True if no problems
    * False if problems: found more than one required version
    """
    return (col[col.notnull()].nunique() <= 1)

# %%
def color_by_type(val):
    if val == 'dependency':
        return 'color: red'
    elif val == 'development_dependency':
        return 'color: orange'
    else:
        return ''

def color_by_dep_type(data):
    return df_piv['type'].loc[data.index, data.columns].applymap(color_by_type)

# %%
(df_piv['version'].loc[:, ~df_piv['version'].apply(check_versions)].fillna('').style
   .apply(color_by_dep_type, axis=None)
   .set_caption("Gem versions. Red = add_dependency, orange = add_development_dependency (add_runtime_dependency not handled).\nList of branches used (develop otherwise):\n{d}".format(d=bump_branches))
)
# Out:
# <style  type="text/css" >
#     #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow0_col1 {
#             color:  red;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow0_col2 {
#             color:  red;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow0_col8 {
#             color:  orange;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow0_col9 {
#             color:  red;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow1_col8 {
#             color:  orange;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow2_col0 {
#             color:  orange;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow2_col8 {
#             color:  red;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow2_col10 {
#             color:  orange;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow2_col11 {
#             color:  red;
#         }    #T_f28a33e8_5d45_11ea_87a9_6045cba1582crow2_col12 {
#             color:  red;
# ...

# %% [markdown]
# ## Save to HTML for sharing

# %%
def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])


def getStyles():
    styles = [
        hover(),
        dict(selector="tr:nth-child(2n+1)", props=[('background', '#f5f5f5')]),
        dict(selector="td", props=[("text-align", "center")]),
        dict(selector="caption", props=[("caption-side", "bottom"),
                                        ("color", "grey")])
    ]
    return styles



html = (df_piv['version'].loc[:, ~df_piv['version'].apply(check_versions)].fillna('').style
   .set_table_attributes('style="border:1px solid black;'
                                     'border-collapse:collapse;"')
   .set_properties(**{'border': '1px solid black',
                                  'border-collapse': 'collapse',
                                  'border-spacing': '0px'})
   .apply(color_by_dep_type, axis=None)
   .set_table_styles(getStyles())
   .set_caption("Gem versions. Red = add_dependency, orange = add_development_dependency (add_runtime_dependency not handled).\nList of branches used (develop otherwise):\n{d}".format(d=bump_branches))
).render()

with open('result.html', 'w') as f:
    f.write(html)
